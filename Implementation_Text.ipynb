# %% [markdown]
# # Video 1

# %%
import speech_recognition as sr
import moviepy.editor as mp

clip = mp.VideoFileClip(r"Test1.mp4")
clip.audio.write_audiofile(r"result1.wav")

r = sr.Recognizer()
audio = sr.AudioFile("result1.wav")
with audio as source:
    audio_file = r.record(source)
    
result = r.recognize_google(audio_file)
    
print(result)

with open('result_text1.txt', mode='w') as file:
    file.write(result)
# Out:
# MoviePy - Writing audio in result1.wav
# MoviePy - Done.
# hello I don't like you I hate you

# %% [markdown]
# # Type 1

# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from tensorflow.keras.models import load_model
import pickle

# Load the test data
test_data = pd.read_table('result_text1.txt', delimiter=';', header=None)
test_data.columns = ["text"]

# Load the encoder
with open("encoder.pkl", "rb") as encoder_file:
    loaded_encoder = pickle.load(encoder_file)

# Load the CountVectorizer
with open("CountVectorizer.pkl", "rb") as cv_file:
    loaded_cv = pickle.load(cv_file)

# Preprocess the test data
def preprocess_test_data(text):
    ps = PorterStemmer()
    review = re.sub('[^a-zA-Z]', ' ', text) # leave only characters from a to z
    review = review.lower() # lower the text
    review = review.split() # turn string into list of words
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')] # delete stop words like I, and, OR
    return " ".join(review)

test_data['text'] = test_data['text'].apply(preprocess_test_data)

# Transform text data into numerical representation using CountVectorizer
X_test = loaded_cv.transform(test_data['text']).toarray()

# Load the trained model
loaded_model = load_model("my_model.h5")

# Make predictions
predictions = loaded_model.predict(X_test)

# Get the labels from the encoder
labels = loaded_encoder.classes_

# Create a DataFrame to store the results including probabilities of all classes
results_df = pd.DataFrame(columns=['Text'] + list(labels))

# Add text to the DataFrame
results_df['Text'] = test_data['text']

# Add predicted probabilities for each class
for i, label in enumerate(labels):
    results_df[label] = predictions[:, i]

# Add predicted labels and accuracy
predicted_label_indices = np.argmax(predictions, axis=1)
predicted_labels = loaded_encoder.inverse_transform(predicted_label_indices)
results_df['Predicted'] = predicted_labels
results_df['Accuracy'] = np.max(predictions, axis=1)

# Print the DataFrame
print(results_df)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
#               Text     anger      fear       joy      love   sadness  \
# 0  hello like hate  0.278652  0.006498  0.021774  0.000637  0.689167
#
#    surprise Predicted  Accuracy
# 0  0.003273   sadness  0.689167

# %% [markdown]
# # Type 2

# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from tensorflow.keras.models import load_model
import pickle

# Load the test data
test_data = pd.read_table('result_text1.txt', delimiter=';', header=None)
test_data.columns = ["text"]

# Load the encoder
with open("encoder.pkl", "rb") as encoder_file:
    loaded_encoder = pickle.load(encoder_file)

# Load the CountVectorizer
with open("CountVectorizer.pkl", "rb") as cv_file:
    loaded_cv = pickle.load(cv_file)

# Preprocess the test data
def preprocess_test_data(text):
    ps = PorterStemmer()
    review = re.sub('[^a-zA-Z]', ' ', text) # leave only characters from a to z
    review = review.lower() # lower the text
    review = review.split() # turn string into list of words
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')] # delete stop words like I, and, OR
    return " ".join(review)

test_data['text'] = test_data['text'].apply(preprocess_test_data)

# Transform text data into numerical representation using CountVectorizer
X_test = loaded_cv.transform(test_data['text']).toarray()

# Load the trained model
loaded_model = load_model("my_model.h5")

# Make predictions
predictions = loaded_model.predict(X_test)

# Convert predictions to labels
predicted_label_indices = np.argmax(predictions, axis=1) # index of max value

# Extract the probability of the predicted class for each sample
predicted_probabilities = np.max(predictions, axis=1) # actual max value

predicted_labels = loaded_encoder.inverse_transform(predicted_label_indices)

# Create a DataFrame to include all probabilities of all classes
results_df_all_probs = pd.DataFrame({
    'Text': test_data['text'],
    'Anger': predictions[:, 0],
    'Fear': predictions[:, 1],
    'Joy': predictions[:, 2],
    'Love': predictions[:, 3],
    'Sadness': predictions[:, 4],
    'Surprise': predictions[:, 5],
})

# Print probabilities for each emotion label
for emotion in results_df_all_probs.columns[1:]:
    print(emotion)
    print(results_df_all_probs[emotion].iloc[0])
    print()

# Create the final DataFrame without probabilities
results_df = pd.DataFrame({
    'Text': test_data['text'],
    'Predicted': predicted_labels,
    'Accuracy': predicted_probabilities
})

# Print the final DataFrame
print(results_df)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Anger
# 0.27865157
#
# Fear
# 0.006497684
#
# Joy
# 0.021774383
#
# Love
# 0.000636529
#
# Sadness
# 0.68916726
#
# Surprise
# 0.0032725264
#
#               Text Predicted  Accuracy
# 0  hello like hate   sadness  0.689167

# %% [markdown]
# # Video 2

# %%
import speech_recognition as sr
import moviepy.editor as mp

clip = mp.VideoFileClip(r"Test2.mp4")
clip.audio.write_audiofile(r"result2.wav")

r = sr.Recognizer()
audio = sr.AudioFile("result2.wav")
with audio as source:
    audio_file = r.record(source)
    
result = r.recognize_google(audio_file)
    
print(result)

with open('result_text2.txt', mode='w') as file:
    file.write(result)
# Out:
# MoviePy - Writing audio in result2.wav
# MoviePy - Done.
# hi I am heshika and I love doing this project

# %% [markdown]
# # Type 1

# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from tensorflow.keras.models import load_model
import pickle

# Load the test data
test_data = pd.read_table('result_text2.txt', delimiter=';', header=None)
test_data.columns = ["text"]

# Load the encoder
with open("encoder.pkl", "rb") as encoder_file:
    loaded_encoder = pickle.load(encoder_file)

# Load the CountVectorizer
with open("CountVectorizer.pkl", "rb") as cv_file:
    loaded_cv = pickle.load(cv_file)

# Preprocess the test data
def preprocess_test_data(text):
    ps = PorterStemmer()
    review = re.sub('[^a-zA-Z]', ' ', text) # leave only characters from a to z
    review = review.lower() # lower the text
    review = review.split() # turn string into list of words
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')] # delete stop words like I, and, OR
    return " ".join(review)

test_data['text'] = test_data['text'].apply(preprocess_test_data)

# Transform text data into numerical representation using CountVectorizer
X_test = loaded_cv.transform(test_data['text']).toarray()

# Load the trained model
loaded_model = load_model("my_model.h5")

# Make predictions
predictions = loaded_model.predict(X_test)

# Convert predictions to labels
predicted_label_indices = np.argmax(predictions, axis=1) # index of max value

# Extract the probability of the predicted class for each sample
predicted_probabilities = np.max(predictions, axis=1) # actual max value

predicted_labels = loaded_encoder.inverse_transform(predicted_label_indices)

# Create a DataFrame to include all probabilities of all classes
results_df_all_probs = pd.DataFrame({
    'Text': test_data['text'],
    'Anger': predictions[:, 0],
    'Fear': predictions[:, 1],
    'Joy': predictions[:, 2],
    'Love': predictions[:, 3],
    'Sadness': predictions[:, 4],
    'Surprise': predictions[:, 5],
})

# Print probabilities for each emotion label
for emotion in results_df_all_probs.columns[1:]:
    print(emotion)
    print(results_df_all_probs[emotion].iloc[0])
    print()

# Create the final DataFrame without probabilities
results_df = pd.DataFrame({
    'Text': test_data['text'],
    'Predicted': predicted_labels,
    'Accuracy': predicted_probabilities
})

# Print the final DataFrame
print(results_df)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Anger
# 0.01864444
#
# Fear
# 3.2643595e-05
#
# Joy
# 0.27540162
#
# Love
# 0.64958507
#
# Sadness
# 0.05633547
#
# Surprise
# 7.51576e-07
#
#                       Text Predicted  Accuracy
# 0  hi heshika love project      love  0.649585

# %% [markdown]
# # For Continuos Video

# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from tensorflow.keras.models import load_model
import pickle
import cv2

# Load the encoder
with open("encoder.pkl", "rb") as encoder_file:
    loaded_encoder = pickle.load(encoder_file)

# Load the CountVectorizer
with open("CountVectorizer.pkl", "rb") as cv_file:
    loaded_cv = pickle.load(cv_file)

# Load the trained model
loaded_model = load_model("my_model.h5")

# Preprocess the test data
def preprocess_test_data(text):
    ps = PorterStemmer()
    review = re.sub('[^a-zA-Z]', ' ', text)  # leave only characters from a to z
    review = review.lower()  # lower the text
    review = review.split()  # turn string into list of words
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]  # delete stop words like I, and, OR
    return " ".join(review)

# Function to process video frames
def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    frame_count = 0

    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            break

        # Perform emotion recognition on the frame
        text_from_frame = perform_emotion_recognition(frame)

        # Preprocess the text
        preprocessed_text = preprocess_test_data(text_from_frame)

        # Transform text data into numerical representation
        X_frame = loaded_cv.transform([preprocessed_text]).toarray()

        # Make predictions
        prediction = loaded_model.predict(X_frame)

        # Convert predictions to labels
        predicted_label_index = np.argmax(prediction)
        predicted_label = loaded_encoder.inverse_transform([predicted_label_index])[0]

        # Print the result for this frame
        print(f"Frame {frame_count}: Predicted Emotion - {predicted_label}")

        frame_count += 1

    cap.release()
    cv2.destroyAllWindows()

def perform_emotion_recognition(frame):
    # Use text detection methods from OpenCV to extract text from the frame
    # This is just a placeholder for demonstration, actual implementation may vary
    # You can implement your own text detection method or use pre-trained models
    # For simplicity, we'll just return a placeholder text
    return "Text from the frame"

# Call the function with the video path
video_path = "Test3.mp4"
process_video(video_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Frame 0: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Frame 1: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 2: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 3: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Frame 4: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Frame 5: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 6: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 7: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Frame 8: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Frame 9: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Frame 10: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Frame 11: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Frame 12: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 13: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Frame 14: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 15: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 16: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 17: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Frame 18: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Frame 19: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Frame 20: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Frame 21: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Frame 22: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Frame 23: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 24: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Frame 25: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Frame 26: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Frame 27: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 28: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 29: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Frame 30: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Frame 31: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 32: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 33: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 34: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Frame 35: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Frame 36: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Frame 37: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Frame 38: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Frame 39: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Frame 40: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 41: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Frame 42: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 43: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 44: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Frame 45: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Frame 46: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Frame 47: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Frame 48: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Frame 49: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Frame 50: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Frame 51: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 52: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Frame 53: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Frame 54: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Frame 55: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Frame 56: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 57: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 58: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Frame 59: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Frame 60: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Frame 61: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Frame 62: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 63: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Frame 64: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Frame 65: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Frame 66: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 67: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Frame 68: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 69: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 70: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 71: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 72: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Frame 73: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Frame 74: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Frame 75: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 76: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 77: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 78: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Frame 79: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Frame 80: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Frame 81: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Frame 82: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Frame 83: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 84: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Frame 85: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 86: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 87: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 88: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 89: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 90: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Frame 91: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Frame 92: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Frame 93: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 94: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Frame 95: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Frame 96: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Frame 97: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Frame 98: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 99: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 100: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 101: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Frame 102: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Frame 103: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Frame 104: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 105: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Frame 106: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 107: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Frame 108: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Frame 109: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Frame 110: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 111: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 112: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Frame 113: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 114: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Frame 115: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Frame 116: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Frame 117: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Frame 118: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 119: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Frame 120: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Frame 121: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 122: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Frame 123: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Frame 124: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Frame 125: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Frame 126: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 127: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Frame 128: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Frame 129: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Frame 130: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 131: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Frame 132: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 133: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 134: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Frame 135: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 136: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Frame 137: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Frame 138: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Frame 139: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Frame 140: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 141: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Frame 142: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Frame 143: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Frame 144: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Frame 145: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Frame 146: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Frame 147: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Frame 148: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 149: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 150: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 151: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Frame 152: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 153: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 154: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Frame 155: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 156: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Frame 157: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Frame 158: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 159: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 160: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 161: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 162: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 163: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Frame 164: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Frame 165: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Frame 166: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 167: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Frame 168: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Frame 169: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Frame 170: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 171: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Frame 172: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Frame 173: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Frame 174: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 175: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Frame 176: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 177: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 178: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 179: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Frame 180: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Frame 181: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 182: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Frame 183: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Frame 184: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Frame 185: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 186: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Frame 187: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Frame 188: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 189: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 190: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 191: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Frame 192: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 193: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 194: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 195: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 196: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 197: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Frame 198: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Frame 199: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 200: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Frame 201: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 202: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Frame 203: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 204: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Frame 205: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Frame 206: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 207: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Frame 208: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 209: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 210: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Frame 211: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 212: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 213: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Frame 214: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Frame 215: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Frame 216: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 217: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Frame 218: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Frame 219: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Frame 220: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 221: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Frame 222: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 223: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 224: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Frame 225: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 226: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Frame 227: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Frame 228: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 229: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 230: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Frame 231: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 232: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Frame 233: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 234: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 235: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 236: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 237: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 238: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 239: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 240: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 241: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Frame 242: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Frame 243: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Frame 244: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Frame 245: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 246: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 247: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 248: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 249: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 250: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 251: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 252: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Frame 253: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Frame 254: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Frame 255: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Frame 256: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Frame 257: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Frame 258: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Frame 259: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Frame 260: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Frame 261: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 262: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 263: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Frame 264: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 265: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Frame 266: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Frame 267: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 268: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 269: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Frame 270: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 271: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Frame 272: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Frame 273: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Frame 274: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Frame 275: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 276: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Frame 277: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 278: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Frame 279: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Frame 280: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Frame 281: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Frame 282: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 283: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Frame 284: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Frame 285: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Frame 286: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Frame 287: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Frame 288: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Frame 289: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Frame 290: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Frame 291: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Frame 292: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Frame 293: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Frame 294: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Frame 295: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Frame 296: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Frame 297: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 298: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Frame 299: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Frame 300: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Frame 301: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Frame 302: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Frame 303: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Frame 304: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Frame 305: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Frame 306: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Frame 307: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Frame 308: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Frame 309: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Frame 310: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Frame 311: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Frame 312: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Frame 313: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Frame 314: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Frame 315: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Frame 316: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Frame 317: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 318: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Frame 319: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 320: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Frame 321: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Frame 322: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Frame 323: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Frame 324: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Frame 325: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Frame 326: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Frame 327: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Frame 328: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Frame 329: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Frame 330: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 331: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Frame 332: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Frame 333: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Frame 334: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Frame 335: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Frame 336: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Frame 337: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Frame 338: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Frame 339: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Frame 340: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Frame 341: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Frame 342: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Frame 343: Predicted Emotion - fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Frame 344: Predicted Emotion - fear

# %%
pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\kumar_lf3uub3\documents\python\lib\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\kumar_lf3uub3\documents\python\lib\site-packages (from pytesseract) (9.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\kumar_lf3uub3\documents\python\lib\site-packages (from packaging>=21.3->pytesseract) (3.0.9)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10
# Note: you may need to restart the kernel to use updated packages.

# %%
#Tesseract can be used to extract text from video frames. (google)

# %%
#If you prefer not to use Tesseract OCR and would like an alternative method to extract text from video frames, you can explore other options.
#One alternative approach is to use pre-trained deep learning models for text detection and recognition, such as EAST (Efficient and Accurate Scene Text Detection) for text detection and CRNN (Convolutional Recurrent Neural Network) for text recognition.

# %%
import cv2  # Or your preferred video library
import speech_recognition as sr  # Or your preferred audio library
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from tensorflow.keras.models import load_model
import pickle

# Load the encoder
with open("encoder.pkl", "rb") as encoder_file:
    loaded_encoder = pickle.load(encoder_file)

# Load the CountVectorizer
with open("CountVectorizer.pkl", "rb") as cv_file:
    loaded_cv = pickle.load(cv_file)

# Load the trained model
loaded_model = load_model("my_model.h5")

# Preprocess the test data
def preprocess_test_data(text):
    ps = PorterStemmer()
    review = re.sub('[^a-zA-Z]', ' ', text)  # leave only characters from a to z
    review = review.lower()  # lower the text
    review = review.split()  # turn string into list of words
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]  # delete stop words like I, and, OR
    return " ".join(review)

def extract_video_and_audio(cap, chunk_size):
    frames = []
    audio_chunks = []

    # Extract frames for chunk_size duration
    for _ in range(int(cap.get(cv2.CAP_PROP_FPS) * chunk_size)):
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)

    # Extract audio for chunk_size duration
    # Implement your audio extraction logic here
    # This is just a placeholder for demonstration
    audio_chunk = "Placeholder audio chunk"  

    return frames, audio_chunk

def process_video_chunk(video_chunk, audio_chunk):
    text = transcribe_audio(audio_chunk)  # Use speech-to-text
    preprocessed_text = preprocess_test_data(text)
    X = loaded_cv.transform([preprocessed_text]).toarray()  
    prediction = loaded_model.predict(X)
    
    # Assuming prediction is a one-hot encoded vector
    predicted_label_index = np.argmax(prediction)
    predicted_label = loaded_encoder.inverse_transform([predicted_label_index])[0]

    return predicted_label

def transcribe_audio(audio_chunk):
    # This is just a placeholder for demonstration
    # Implement your actual audio transcription logic using your preferred library
    return "Placeholder text from audio"

video_path = "Test3.mp4"
cap = cv2.VideoCapture(video_path)
# ... Set up video processing, audio extraction with your chosen library

chunk_size = 5  # Seconds
while True:
    video_chunk, audio_chunk = extract_video_and_audio(cap, chunk_size)

    if not video_chunk:  # End of video
        break

    emotion = process_video_chunk(video_chunk, audio_chunk)
    print("Emotion detected:", emotion)

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000022DB8BB8820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000022DB8BB8820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Emotion detected: fear

# %%
import cv2  # Or your preferred video library
import speech_recognition as sr  # Or your preferred audio library
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from tensorflow.keras.models import load_model
import pickle

# Load the encoder
with open("encoder.pkl", "rb") as encoder_file:
    loaded_encoder = pickle.load(encoder_file)

# Load the CountVectorizer
with open("CountVectorizer.pkl", "rb") as cv_file:
    loaded_cv = pickle.load(cv_file)

# Load the trained model
loaded_model = load_model("my_model.h5")

# Preprocess the test data
def preprocess_test_data(text):
    ps = PorterStemmer()
    review = re.sub('[^a-zA-Z]', ' ', text)  # leave only characters from a to z
    review = review.lower()  # lower the text
    review = review.split()  # turn string into list of words
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]  # delete stop words like I, and, OR
    return " ".join(review)

def extract_video_and_audio(cap, chunk_size):
    frames = []
    audio_chunks = []

    # Extract frames for chunk_size duration
    for _ in range(int(cap.get(cv2.CAP_PROP_FPS) * chunk_size)):
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)

    # Extract audio for chunk_size duration
    # Implement your audio extraction logic here
    # This is just a placeholder for demonstration
    audio_chunk = "Placeholder audio chunk"  

    return frames, audio_chunk

def process_video_chunk(video_chunk, audio_chunk):
    text = transcribe_audio(audio_chunk)  # Use speech-to-text
    preprocessed_text = preprocess_test_data(text)
    X = loaded_cv.transform([preprocessed_text]).toarray()  
    prediction = loaded_model.predict(X)
    
    # Assuming prediction is a one-hot encoded vector
    predicted_label_index = np.argmax(prediction)
    predicted_label = loaded_encoder.inverse_transform([predicted_label_index])[0]

    return predicted_label

def transcribe_audio(audio_chunk):
    # This is just a placeholder for demonstration
    # Implement your actual audio transcription logic using your preferred library
    return "Placeholder text from audio"

video_path = "long.mp4"
cap = cv2.VideoCapture(video_path)
# ... Set up video processing, audio extraction with your chosen library

chunk_size = 5  # Seconds
while True:
    video_chunk, audio_chunk = extract_video_and_audio(cap, chunk_size)

    if not video_chunk:  # End of video
        break

    emotion = process_video_chunk(video_chunk, audio_chunk)
    print("Emotion detected:", emotion)

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000022DB9B68CA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000022DB9B68CA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Emotion detected: fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Emotion detected: fear
